# %%
x = 55
R = 0.5
A = "Evil Code"

print(x)
print(R)
print(A)
# Out:
# 55
# 0.5
# Evil Code

# %% [markdown]
# # The print command writes out the variable. I created 3 variables. Their names are x,R, and A, x is an integer, R is a float, and A is a string
# # I used the print command to print them

# %%
jar1 = 5
jar2 = 10
hello = "hello"
print(jar1 + jar2 + hello)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 jar2 = 10
#       3 hello = "hello"
# ----> 4 print(jar1 + jar2 + hello)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # The code does not work because it is trying to add a string into an integer.

# %%
jar1 = 5
jar2 = 10
print(jar2)

jar2 = jar1
print(jar2)
# Out:
# 10
# 5

# %% [markdown]
# # Whatever is on the left of the equals sign gets set to the value on the right of the equals sign

# %%
name = "Raphael"
age = 16
print("My name is",name, "and I am",age,"years old!")
# Out:
# My name is Raphael and I am 16 years old!

# %%
my_name = "Raphael"
my_Name = "Raphael"
my_life = "Is a book" 


print(my_name.upper())
print(my_Name.lower())
# Out:
# RAPHAEL
# raphael

# %% [markdown]
# ### print is a function. I use it by itself and I put what I want to pring in the parenthesis.
# ### .upper() is a method. UPPER lower Title

# %%
my_life = "is a book"
print(my_life.title())
# Out:
# Is A Book

# %%
first_name = "Raphael"
last_name = "Kaplan"
fullname = f"{first_name} {last_name}"

print(first_name,last_name)
print(fullname)
print(f"Hello, {fullname.title()}!")
# Out:
# Raphael Kaplan
# Raphael Kaplan
# Hello, Raphael Kaplan!

# %% [markdown]
# ### to put two variables into one variable. make the variable like always, add an f at the beginning. add "".  Put {} around each variable. To print the compound variable. You also have to put an f before the ""

# %%
print("grocery list: \n\tapples \n\tbannanas \n\toranges \n\tmilk \n\tcelery \n\tpeanut butter \n\tbutter \n\tbread")
# Out:
# grocery list:
# 	apples
# 	bannanas
# 	oranges
# 	milk
# 	celery
# 	peanut butter
# 	butter
# 	bread

# %% [markdown]
# ### \n creates a new line. \t is the same as tab

# %%
# There are three methods to clear white space: rstrip(), lstrip(), and strip()
name = " Raphael "
name_cleaned = name.strip().upper()
print(name)
print(name_cleaned)
# Out:
#  Raphael
# RAPHAEL

# %% [markdown]
# # There are three methods to clear whitespace: rstrip(), lstrip(), and strip()
