# %% [markdown]
# # Module 2 Notes: List

# %%
words = ["Hello", "pizza", "school", "friendly", "words"]
print(words)
print(words[0])
print(words[4].upper())
print(words[-1].upper())

print(words[1].title())

print("One of my favorite works is:", words[3])
my_sentence = f"One of my favorite words is: {words[3]}"
print(my_sentence)

length = len(words)
print(length)
print(len(words))

sentence_2 = f"I love {words[1]} and {words[3]} but I hate {words[2]} my list of favorite words has {len(words)} items."
print(sentence_2)
# Out:
# ['Hello', 'pizza', 'school', 'friendly', 'words']
# Hello
# WORDS
# WORDS
# Pizza
# One of my favorite works is: friendly
# One of my favorite words is: friendly
# 5
# 5
# I love pizza and friendly but I hate school my list of favorite words has 5 items.

# %% [markdown]
# ### Every item in a list has a location starting at 0. We can also start from the end with -1. The location is referred to as an index. So the first item in a list is at index 0. We can use the items in the list as is appropriate according to their type. If the items are strings, we can call string methods on them. If they are numbers, we can do math with them. The way we access a particular item in a list is the name_of_list[index]. There is a len function that will tell us how long the list is.

# %%
print("Grocery List\nmilk")
# Out:
# Grocery List
# milk

# %%
birthday = ["December", "14", "2009"]
Birthday_sentence = f"I was born in the year {birthday[2]} on the day {birthday[1]} of the month {birthday[0]}."
print(Birthday_sentence)
# Out:
# I was born in the year 2009 on the day 14 of the month December.

# %%
sibilings = ["Nathan", "Lauran", "James", "Preston"]
favorite_sibiling = f"I like {sibilings[0]} the most, I like {sibilings[1]} the second most, I like {sibilings[2]} the third most, and I like {sibilings[3]} the least."
sibilings.append("Joey")
print(favorite_sibiling)


sibilings[0] = "Nathaniel"
print(favorite_sibiling)
# Out:
# I like Nathan the most, I like Lauran the second most, I like James the third most, and I like Preston the least.
# I like Nathan the most, I like Lauran the second most, I like James the third most, and I like Preston the least.

# %%
grades = [2, 30, 70, 100, 90]
grades.insert(1, 75)
print(grades)
print((grades[0] + grades[1] + grades[2] + grades [3] + grades [4])/5)
# Out:
# [2, 75, 30, 70, 100, 90]
# 55.4

# %% [markdown]
# ### I can change the value of an item in the list by resetting it. For example my_lift[1] = "new value". I can also use methos on lists. Some methods I can use are .append() and .insert(). Append adds an item to the end of the list. insert adds an item somewhere in the list and shifts everything down to the right. Append takes one parameter which means I put one value in () and that value is the thing I'm adding to the list. Insert take two parameters. The first is the location, the second is the item to insert at that location.

# %%
activities = ["Golf", "Eat", "sleep", "Code", "talk", "friends"]
print(activities)

activities.remove("Code")
## the result is ['Golf', 'Eat', 'sleep', 'talk', 'friends']
#activities.pop(2)
## the result is 'sleep
print(activities)
# Out:
# ['Golf', 'Eat', 'sleep', 'Code', 'talk', 'friends']
# ['Golf', 'Eat', 'sleep', 'talk', 'friends']

# %% [markdown]
# ### pop requires me to know the index of the value I'm trying to remove wheras remove requires me to know the exact value

# %%
numbers = [3, 5, 8, 10, 11, 28, 42, 77, 101, 108, 2002]
numbers [2] = 1

numbers.insert(2,50)

numbers.remove(108)

numbers.pop(9)

numbers.append(100)

numbers.pop(-2)

numbers.pop(5)


#use del to delete the 5
del numbers[1]

print(numbers)
# Out:
# [3, 50, 1, 10, 28, 42, 77, 100]

# %%
list_with_five_items = ["burger", "fries", "ketchup", "monkey", "banana"]
list_with_five_items.append("Hello")
list_with_five_items.insert(3, 1)
print(list_with_five_items) 

list_with_five_items.pop(1)
print(list_with_five_items) 
list_with_five_items.pop(5)
print(list_with_five_items)
list_with_five_items.pop(1)
print(list_with_five_items)
y = list_with_five_items.pop()
print(f"The last in my list was {y}")
# Out:
# ['burger', 'fries', 'ketchup', 1, 'monkey', 'banana', 'Hello']
# ['burger', 'ketchup', 1, 'monkey', 'banana', 'Hello']
# ['burger', 'ketchup', 1, 'monkey', 'banana']
# ['burger', 1, 'monkey', 'banana']
# The last in my list was banana

# %% [markdown]
# ### pop has three functionlities. 1. I tcan came by index for sample: my_list.pop(1) 2. it can store the value it deletes for a second so you can store it in a variable. For example y = my_list.pop(1) 3. It can make the executive decision to delete the last tiem if you don't give it any additional value. For example: my_list.pop()

# %%
elements = ["hydrogen", "helium", "lithium", "beryllium", "boron", "rutherfordium", "carbon"]
print(elements)
elements.sort()
elements.reverse()
print(elements)

flowers = ["rose", "lily", "daisy", "tulip", "sunflower", "orchid", "lavender"]
print(sorted(flowers))
print(flowers)

print ("rose" in flowers)
print("violet" in flowers)
# Out:
# ['hydrogen', 'helium', 'lithium', 'beryllium', 'boron', 'rutherfordium', 'carbon']
# ['rutherfordium', 'lithium', 'hydrogen', 'helium', 'carbon', 'boron', 'beryllium']
# ['daisy', 'lavender', 'lily', 'orchid', 'rose', 'sunflower', 'tulip']
# ['rose', 'lily', 'daisy', 'tulip', 'sunflower', 'orchid', 'lavender']
# True
# False

# %%
books = ["harry potter", "the hunger games", "the great gatsby", "to kill a mockingbird", "the catcher in the rye"]
books[0] = books[0].title()
books[1] = books[1].title()
books[2] = books[2].title()
books[3] = books[3].title()
books[4] = books[4].title()
print(books)
# Out:
# ['Harry Potter', 'The Hunger Games', 'The Great Gatsby', 'To Kill A Mockingbird', 'The Catcher In The Rye']

# %% [markdown]
# ### .sort() is a mehtod that will chagne the order of the sit to be in alphabetical roder .reverse()reverses the order of a list. Both of these fundamentally change the order of the list permanently. On the other hand, .sorted() is a funtiomn that can temporarily sort a list without permanently changing it.

# %%
teams = ["rams", "Dogers", "Lakers"]
print(teams)
print(teams[0])
print(teams[1])
for thing in teams:
    print(thing)
    print("hello")
    print("Raphael")
print("loyola")
print("goodbye")
# Out:
# ['rams', 'Dogers', 'Lakers']
# rams
# Dogers
# rams
# hello
# Raphael
# Dogers
# hello
# Raphael
# Lakers
# hello
# Raphael
# loyola
# goodbye
